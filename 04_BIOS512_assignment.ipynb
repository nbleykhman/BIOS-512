# %% [markdown]
# # BIOS512 Assignment #4

# %% [markdown]
# 🌬 For this assignment we are going to work with [Canada wind turbine](https://github.com/rfordatascience/tidytuesday/blob/master/data/2020/2020-10-27/readme.md) data from TidyTuesday. 💨

# %% [markdown]
# Use `read_csv` to load the data from the TidyTuesday GitHub repository. The project URL is can be found at [https://github.com/rfordatascience/tidytuesday/blob/master/data/2020/2020-10-27/](https://github.com/rfordatascience/tidytuesday/blob/master/data/2020/2020-10-27/).

# %%
library('tidyverse')
windmills = read.csv('https://raw.githubusercontent.com/rfordatascience/tidytuesday/refs/heads/master/data/2020/2020-10-27/wind-turbine.csv')
windmills |> head()
# Out:
#   objectid province_territory project_name           total_project_capacity_mw
# 1 1        Alberta            Optimist Wind Energy    0.90
# 2 2        Alberta            Castle River Wind Farm 44.00
# 3 3        Alberta            Waterton Wind Turbines  3.78
# 4 4        Alberta            Waterton Wind Turbines  3.78
# 5 5        Alberta            Waterton Wind Turbines  3.78
# 6 6        Alberta            Waterton Wind Turbines  3.78
#   turbine_identifier turbine_number_in_project turbine_rated_capacity_k_w
# 1 OWE1               1/2                       150
# 2 CRW1               1/60                      600
# 3 WWT1               1/6                       600
# 4 WWT2               2/6                       600
# 5 WWT3               3/6                       600
# 6 WWT4               4/6                       660
#   rotor_diameter_m hub_height_m manufacturer model     commissioning_date
# 1 23               30           Bonus        AN 150/30 1993
# 2 44               40           Vestas       V44/600   1997
# 3 44               50           Vestas       V44/600   1998
# 4 44               50           Vestas       V44/600   1998
# 5 44               50           Vestas       V44/600   1998
# 6 47               50           Vestas       V47/660   2000
#   latitude longitude notes
# 1 49.52535 -114.0548 NA
# 2 49.51264 -114.0357 NA
# 3 49.23307 -113.6549 NA
# 4 49.23303 -113.6302 NA
# 5 49.21755 -113.6802 NA
# 6 49.21773 -113.6579 NA

# %% [markdown]
# Each row in the table represents a single turbine.

# %% [markdown]
# Make a bar chart 📊 **sorted by frequency** of turbine count per province territory. (Hint: `fct_infreq` will sort your factor levels by frequency for subsequent plotting)

# %%
options(repr.plot.height = 3)

windmills |>
   mutate(province_territory = fct_infreq(province_territory) |> fct_rev()) |>
   ggplot(aes(y=province_territory)) + 
   geom_bar() +
   labs(title = "Frequency of Turbine Count per Province Territory") +
   ylab("Province Territory") +
   xlab("Count")
# Out:
# plot without title

# %% [markdown]
# Make a bar chart **sorted by frequency** of turbine count per manufacturer. **Group the low frequency manufacturers into an `Other` category**.
#
# **Bonus:** Can you force the `Other` category to be the last bar?

# %%
options(repr.plot.height = 3)

windmills |>
    mutate(manufacturer = fct_lump_n(manufacturer, n = 5)) |>
    mutate(manufacturer = fct_infreq(manufacturer) |> fct_rev()) |>
    ggplot(aes(y=manufacturer)) + 
    geom_bar()
# Out:
# plot without title

# %% [markdown]
# Let's make a map of where each turbine is located. 🗺️
#
# In the cell below ⬇️ load the `mapdata` package.

# %%
library('mapdata')

# %% [markdown]
# Now we can retrieve the "data" for a map of Canada. Run this code:

# %%
canada = map_data('world', region='Canada')  
canada
# Out:
#       long      lat      group order region subregion
# 1     -59.78760 43.93960 1      1    Canada Sable Island
# 2     -59.92227 43.90391 1      2    Canada Sable Island
# 3     -60.03775 43.90664 1      3    Canada Sable Island
# 4     -60.11426 43.93911 1      4    Canada Sable Island
# 5     -60.11748 43.95337 1      5    Canada Sable Island
# 6     -59.93604 43.93960 1      6    Canada Sable Island
# 7     -59.86636 43.94717 1      7    Canada Sable Island
# 8     -59.72715 44.00283 1      8    Canada Sable Island
# 9     -59.78760 43.93960 1      9    Canada Sable Island
# 11    -66.27377 44.29229 2     11    Canada 5
# 12    -66.32412 44.25732 2     12    Canada 5
# 13    -66.31191 44.29160 2     13    Canada 5
# 14    -66.25049 44.37901 2     14    Canada 5
# 15    -66.21035 44.39204 2     15    Canada 5
# 16    -66.27377 44.29229 2     16    Canada 5
# 18    -66.76250 44.68179 3     18    Canada Grand Manan Island
# 19    -66.89707 44.62891 3     19    Canada Grand Manan Island
# 20    -66.84473 44.76392 3     20    Canada Grand Manan Island
# 21    -66.80215 44.80537 3     21    Canada Grand Manan Island
# 22    -66.74541 44.79141 3     22    Canada Grand Manan Island
# 23    -66.75337 44.70981 3     23    Canada Grand Manan Island
# 24    -66.76250 44.68179 3     24    Canada Grand Manan Island
# 26    -60.96157 45.48994 4     26    Canada 9
# 27    -61.00288 45.48174 4     27    Canada 9
# 28    -61.01250 45.49604 4     28    Canada 9
# 29    -61.07617 45.53730 4     29    Canada 9
# 30    -61.08174 45.55781 4     30    Canada 9
# 31    -61.02598 45.57734 4     31    Canada 9
# 32    -60.91245 45.56729 4     32    Canada 9
# 33    -60.95303 45.51553 4     33    Canada 9
# ⋮     ⋮         ⋮        ⋮     ⋮     ⋮      ⋮
# 11684 -74.41416 83.01314 141   11684 Canada Ellesmere Island
# 11685 -74.19775 82.98901 141   11685 Canada Ellesmere Island
# 11686 -74.05586 82.95538 141   11686 Canada Ellesmere Island
# 11687 -73.91650 82.90420 141   11687 Canada Ellesmere Island
# 11688 -73.70312 82.85185 141   11688 Canada Ellesmere Island
# 11689 -73.27203 82.77158 141   11689 Canada Ellesmere Island
# 11690 -72.65869 82.72163 141   11690 Canada Ellesmere Island
# 11691 -72.77592 82.75566 141   11691 Canada Ellesmere Island
# 11692 -73.23466 82.84424 141   11692 Canada Ellesmere Island
# 11693 -73.44189 82.90484 141   11693 Canada Ellesmere Island
# 11694 -73.44072 82.94585 141   11694 Canada Ellesmere Island
# 11695 -73.40381 82.97715 141   11695 Canada Ellesmere Island
# 11696 -73.33115 82.99878 141   11696 Canada Ellesmere Island
# 11697 -72.81167 83.08120 141   11697 Canada Ellesmere Island
# 11698 -72.06924 83.10606 141   11698 Canada Ellesmere Island
# 11699 -71.98320 83.10142 141   11699 Canada Ellesmere Island
# 11700 -71.40596 82.97485 141   11700 Canada Ellesmere Island
# 11701 -71.13203 82.92304 141   11701 Canada Ellesmere Island
# 11702 -70.94038 82.90224 141   11702 Canada Ellesmere Island
# 11703 -70.93301 82.91128 141   11703 Canada Ellesmere Island
# 11704 -71.19834 82.96958 141   11704 Canada Ellesmere Island
# 11705 -71.40240 83.00127 141   11705 Canada Ellesmere Island
# 11706 -71.42353 83.02114 141   11706 Canada Ellesmere Island
# 11707 -71.08481 83.08266 141   11707 Canada Ellesmere Island
# 11708 -70.87055 83.09814 141   11708 Canada Ellesmere Island
# 11709 -69.96992 83.11611 141   11709 Canada Ellesmere Island
# 11710 -69.86768 83.10962 141   11710 Canada Ellesmere Island
# 11711 -69.78213 83.09253 141   11711 Canada Ellesmere Island
# 11712 -69.56938 83.02490 141   11712 Canada Ellesmere Island
# 11713 -69.48887 83.01680 141   11713 Canada Ellesmere Island

# %% [markdown]
# Are the column names for `latitude` and `longitude` the same for your Canada map data and the turbine data?

# %% [markdown]
# No, the column names for the turbine data is latitude and longitude, while the Canada map is lat and long.

# %% [markdown]
# The code below creates a map of Canada. Modify the code to add the turbine locations.
#
# ❗️ **Hint:** use `geom_point`. Remember to,
# 1. define encodings inside of `geom_point` that work for the **turbine data**, and
# 2. to override the data in `geom_point` to use the **turbine data** instead of the **Canada map data**. ❗️
#
# [This](https://github.com/chuckpr/BIOS512/blob/main/assignments/2024/map.png?raw=true) is what the map should look like...

# %%
ggplot(data = canada) + 
    geom_polygon(aes(x = long, y = lat, group = group), fill = 'coral', color = "white", alpha = 0.5) + 
    coord_quickmap() +
    geom_point(data = windmills,aes(x=longitude,y=latitude),color = 'steelblue',size = 0.5)
# Out:
# plot without title
